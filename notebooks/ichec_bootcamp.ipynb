# %%
Image(url='http://it.uoregon.edu/system/files/imagecache/scale_to_460_x_300/logo_newsichec.jpg')
# Out:
# <img src="http://it.uoregon.edu/system/files/imagecache/scale_to_460_x_300/logo_newsichec.jpg" />

# %%
from IPython.core.display import Image
Image(filename='//home/ubuntu/json_data/notebooks/figs/aws-logo-large.png')

# %%
pwd
# Out:
# u'/home/ubuntu/json_data/notebooks'

# %%
pwd
# Out:
# u'/home/ubuntu/json_data'

# %%
loadpy initial_code_importing_json

# %%
#!/usr/bin/env python
import networkx as nx
import subprocess as sp
from text_analysis import *
from cStringIO import StringIO
import json

import fileinput

#for filename in fileinput.input():
#   pass

filename = '/home/ubuntu/json_data/20120807150601.json.gz'

#unzipped_dirty = sp.check_output( [ 'zcat', filename.split('\n')[0] ])
unzipped_dirty = sp.check_output( [ 'zcat', filename ])

json_data = StringIO(unzipped_dirty.replace(']\n\n[',','))
tweets = json.load(json_data) 


remove = ( 'this that your with have watch #olympics should'
           'being olympics olympic' )

remove = set(remove.split())

#lines = [ t['text'].encode('utf-8') for t in tweets ]
lines = [ t['text'] for t in tweets ]

clean_lines = lines_cleanup( lines, 4, remove)
words = '\n'.join(clean_lines).split()

n_words = 15 
n_nodes = 15

wf = word_freq(words)

sorted_wf = sort_freqs(wf)

popular = sorted_wf[-n_nodes:]
pop_words = [wc[0] for wc in popular]
co_occur = co_occurrences(lines, pop_words)
cutoff = 10

wgraph = co_occurrences_graph(popular, co_occur, cutoff - 1)
wgraph = nx.connected_component_subgraphs(wgraph)[0]
centrality = nx.eigenvector_centrality_numpy(wgraph)
summarize_freq_hist(wf)
summarize_centrality(centrality)
# Out:
# Number of unique words: 1486
#
# 10 least frequent words:
# @nishachittal: -> 1
# 'britishness'? -> 1
#          ever! -> 1
#          sleep -> 1
#     tug-of-war -> 1
#     @isteakers -> 1
#          whose -> 1
#          tweet -> 1
#     disability -> 1
#          daley -> 1
#
# 10 most frequent words:
#     last -> 14
#   should -> 14
#    being -> 15
# olympics -> 16
# boycott: -> 16
#    death -> 16
#     1980 -> 16
#  fastest -> 17
#     gold -> 24
# watching -> 25
#
# Graph centrality
#            1980: 0.387
#        boycott:: 0.387
#           being: 0.374
#         fastest: 0.374
#          1980's: 0.374
#         instead: 0.374
#            800m: 0.374

# %%
plot_word_histogram(wf)

# %%
plot_graph(wgraph)

# %%
pwd
# Out:
# u'/home/ubuntu/json_data/notebooks/figs'

# %% [markdown]
# #the olympics

# %%
Image(url='http://i2.cdn.turner.com/money/2012/07/30/news/economy/olympics-cost/olympics-cost.gi.top.jpg')
# Out:
# <img src="http://i2.cdn.turner.com/money/2012/07/30/news/economy/olympics-cost/olympics-cost.gi.top.jpg" />

# %%
figsize(16,10)

# %%
loadpy json_geo.py

# %%
# !git log --all --graph --pretty=format:'%Cred%h%Creset -%C(yellow)%d%Creset %s %Cgreen(%cr) %C(bold blue)<%an>%Creset' --abbrev-commit --date=relative
# Out:
# ---------------------------------------------------------------------------
# ExceptionPexpect                          Traceback (most recent call last)
# <ipython-input-18-314fa83171d7> in <module>()
# ----> 1 get_ipython().system(u"git log --all --graph --pretty=format:'%Cred%h%Creset -%C(yellow)%d%Creset %s %Cgreen(%cr) %C(bold blue)<%an>%Creset' --abbrev-commit --date=relative")
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in system_piped(self, cmd)
#    2210         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2211         # Instead, we store the exit_code in user_ns.
# -> 2212         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2213
#    2214     def system_raw(self, cmd):
#
# /usr/local/lib/python2.7/dist-packages/IPython/utils/_process_posix.pyc in system(self, cmd)
#     151             #child = pexpect.spawn(pcmd, searchwindowsize=1)
#     152             if hasattr(pexpect, 'spawnb'):
# --> 153                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     154             else:
#     155                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#
# /usr/local/lib/python2.7/dist-packages/IPython/external/pexpect/_pexpect.pyc in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env)
#     454             self.name = '<pexpect factory incomplete>'
#     455         else:
# --> 456             self._spawn (command, args)
#     457
#     458     def __del__(self):
#
# /usr/local/lib/python2.7/dist-packages/IPython/external/pexpect/_pexpect.pyc in _spawn(self, command, args)
#     554                 self.pid, self.child_fd = pty.fork()
#     555             except OSError, e:
# --> 556                 raise ExceptionPexpect('Error! pty.fork() failed: ' + str(e))
#     557         else: # Use internal __fork_pty
#     558             self.pid, self.child_fd = self.__fork_pty()
#
# ExceptionPexpect: Error! pty.fork() failed: [Errno 12] Cannot allocate memory
